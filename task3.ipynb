# %% [markdown]
# <a href="https://colab.research.google.com/github/akr1139/Neural-network-and-fuzzy-systems-CO542/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sbn
from sklearn.metrics import plot_confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# load data set to a dataframe
df = pd.read_csv("iris.csv")

# %%
# pairplot
sbn.pairplot(df)
# to show
plt.savefig('pairplot')
plt.show()

# %%
# drop ID column
df = df.drop(columns = ["Id"], axis=1)

# %%
#seperate features and labels
features = df.iloc[:, 0:4]
labels = df.iloc[:, 4:5]

# %%
#convert labels into numerical data
leb_enc = LabelEncoder()
leb_enc.fit(labels)
labels = leb_enc.transform(labels)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#split data into test and train
x_train, x_test, y_train, y_test = train_test_split(features,labels, train_size=0.8, test_size=0.2)

# %%
#Scale the x_train and x_test data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
# define the MLP and train
clf = MLPClassifier(learning_rate_init=1.00).fit(x_train, y_train)

# %%
#make predictions
test_pred = clf.predict(x_test)
test_pred
# Out:
# array([1, 1, 0, 1, 0, 2, 0, 0, 1, 2, 2, 2, 0, 1, 2, 2, 1, 2, 2, 1, 0, 0,
#        0, 2, 2, 2, 2, 0, 0, 0])

# %%
#confusion matrix
plot_confusion_matrix(clf, x_test, y_test)
plt.show()

# %%
cls_labels = list(leb_enc.classes_)
print(classification_report(y_test, test_pred, target_names=cls_labels) )
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.86      0.86      0.86         7
#  Iris-virginica       0.92      0.92      0.92        12
#
#        accuracy                           0.93        30
#       macro avg       0.92      0.92      0.92        30
#    weighted avg       0.93      0.93      0.93        30

# %%
#100 iterations
# define the MLP and train
clf = MLPClassifier(learning_rate_init=1.00,max_iter=100).fit(x_train, y_train)
#make predictions
test_pred = clf.predict(x_test)
#confusion matrix
plot_confusion_matrix(clf, x_test, y_test)
plt.show()
print(classification_report(y_test, test_pred, target_names=cls_labels) )
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.67      1.00      0.80         8
#  Iris-virginica       1.00      0.67      0.80        12
#
#        accuracy                           0.87        30
#       macro avg       0.89      0.89      0.87        30
#    weighted avg       0.91      0.87      0.87        30

# %%
#300 iterations
# define the MLP and train
clf = MLPClassifier(learning_rate_init=1.00,max_iter=300).fit(x_train, y_train)
#make predictions
test_pred = clf.predict(x_test)
#confusion matrix
plot_confusion_matrix(clf, x_test, y_test)
plt.show()
print(classification_report(y_test, test_pred, target_names=cls_labels) )
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        12
# Iris-versicolor       1.00      0.42      0.59        12
#  Iris-virginica       0.46      1.00      0.63         6
#
#        accuracy                           0.77        30
#       macro avg       0.82      0.81      0.74        30
#    weighted avg       0.89      0.77      0.76        30

# %%
#500 iterations
# define the MLP and train
clf = MLPClassifier(learning_rate_init=1.00,max_iter=500).fit(x_train, y_train)
#make predictions
test_pred = clf.predict(x_test)
#confusion matrix
plot_confusion_matrix(clf, x_test, y_test)
plt.show()
print(classification_report(y_test, test_pred, target_names=cls_labels) )
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      0.83      0.91        12
#  Iris-virginica       0.80      1.00      0.89         8
#
#        accuracy                           0.93        30
#       macro avg       0.93      0.94      0.93        30
#    weighted avg       0.95      0.93      0.93        30

# %%
#split data into test and train 75% 25%
x_train, x_test, y_train, y_test = train_test_split(features,labels, train_size=0.75, test_size=0.25)
#Scale the x_train and x_test data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)
# define the MLP and train
clf = MLPClassifier(learning_rate_init=1.00).fit(x_train, y_train)
#make predictions
test_pred = clf.predict(x_test)
#confusion matrix
plot_confusion_matrix(clf, x_test, y_test)
plt.show()
print(classification_report(y_test, test_pred, target_names=cls_labels) )
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.86      1.00      0.92        12
# Iris-versicolor       0.73      0.80      0.76        10
#  Iris-virginica       1.00      0.81      0.90        16
#
#        accuracy                           0.87        38
#       macro avg       0.86      0.87      0.86        38
#    weighted avg       0.88      0.87      0.87        38

# %%
#split data into test and train 70% 30%
x_train, x_test, y_train, y_test = train_test_split(features,labels, train_size=0.70, test_size=0.30)
#Scale the x_train and x_test data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)
# define the MLP and train
clf = MLPClassifier(learning_rate_init=1.00).fit(x_train, y_train)
#make predictions
test_pred = clf.predict(x_test)
#confusion matrix
plot_confusion_matrix(clf, x_test, y_test)
plt.show()
print(classification_report(y_test, test_pred, target_names=cls_labels) )
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.91      1.00      0.95        10
# Iris-versicolor       0.73      0.94      0.82        17
#  Iris-virginica       1.00      0.67      0.80        18
#
#        accuracy                           0.84        45
#       macro avg       0.88      0.87      0.86        45
#    weighted avg       0.88      0.84      0.84        45

# %%
#split data into test and train 90% 10%
x_train, x_test, y_train, y_test = train_test_split(features,labels, train_size=0.90, test_size=0.10)
#Scale the x_train and x_test data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)
# define the MLP and train
clf = MLPClassifier(learning_rate_init=1.00).fit(x_train, y_train)
#make predictions
test_pred = clf.predict(x_test)
#confusion matrix
plot_confusion_matrix(clf, x_test, y_test)
plt.show()
print(classification_report(y_test, test_pred, target_names=cls_labels) )
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         6
# Iris-versicolor       1.00      0.67      0.80         6
#  Iris-virginica       0.60      1.00      0.75         3
#
#        accuracy                           0.87        15
#       macro avg       0.87      0.89      0.85        15
#    weighted avg       0.92      0.87      0.87        15

# %%
#learning rate 0.002
# define the MLP and train
clf = MLPClassifier(learning_rate_init=0.002).fit(x_train, y_train)
#make predictions
test_pred = clf.predict(x_test)
#confusion matrix
plot_confusion_matrix(clf, x_test, y_test)
plt.show()
print(classification_report(y_test, test_pred, target_names=cls_labels) )
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         9
# Iris-versicolor       0.90      1.00      0.95         9
#  Iris-virginica       1.00      0.92      0.96        12
#
#        accuracy                           0.97        30
#       macro avg       0.97      0.97      0.97        30
#    weighted avg       0.97      0.97      0.97        30

# %%
#learning rate 0.5
# define the MLP and train
clf = MLPClassifier(learning_rate_init=0.5).fit(x_train, y_train)
#make predictions
test_pred = clf.predict(x_test)
#confusion matrix
plot_confusion_matrix(clf, x_test, y_test)
plt.show()
print(classification_report(y_test, test_pred, target_names=cls_labels) )
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         9
# Iris-versicolor       0.82      1.00      0.90         9
#  Iris-virginica       1.00      0.83      0.91        12
#
#        accuracy                           0.93        30
#       macro avg       0.94      0.94      0.94        30
#    weighted avg       0.95      0.93      0.93        30

# %%
#learning rate 1.0
# define the MLP and train
clf = MLPClassifier(learning_rate_init=1.0).fit(x_train, y_train)
#make predictions
test_pred = clf.predict(x_test)
#confusion matrix
plot_confusion_matrix(clf, x_test, y_test)
plt.show()
print(classification_report(y_test, test_pred, target_names=cls_labels) )
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      0.25      0.40         8
#  Iris-virginica       0.60      1.00      0.75         9
#
#        accuracy                           0.80        30
#       macro avg       0.87      0.75      0.72        30
#    weighted avg       0.88      0.80      0.77        30
